# %%
import sys; 
import cv2; print('opencv version:', cv2.__version__)
import pandas as pd; print('panda version: ', pd.__version__)
import random
import numpy as np
import os; 
import os.path;
from random import randint
from pathlib import Path
from sklearn import svm
from matplotlib import pyplot as plt; 
from skimage.filters import threshold_otsu
from skimage.io import imread
from sklearn.model_selection import cross_val_score
print(sys.prefix)
print(os.getcwd())

base_dir = os.getcwd()

def cross_validation(model, num_of_fold, train_data, train_label):
    # this uses the concept of cross validation to measure the accuracy
    # of a model, the num_of_fold determines the type of validation
    # e.g if num_of_fold is 4, then we are performing a 4-fold cross validation
    # it will divide the dataset into 4 and use 1/4 of it for testing
    # and the remaining 3/4 for the training
    accuracy_result = cross_val_score(model, train_data, train_label,
                                      cv=num_of_fold)
    print("Cross Validation Result for ", str(num_of_fold), " -fold")

    print(accuracy_result * 100)

clf = svm.SVC(kernel='linear', probability=True)

target_data = ['5', 'V', '3', 'A', '9', '7', '6', '9', 'S', '4', 'V', '5', 'Y', '5', 'V', '8', '9', '8', '3', 'V', '8', 'O', 'O', '4', '5', '9', 'B', '5', '9', '4', '2', 'X', 'M', 'G', 'C', '1', '9', '0', '1', 'O', 'Y', 'L', '0', '5', '9', 'S', '0', '9', 'O', 'K', '8', 'S', '5', '3', 'F', '1', '9', '8', 'O', '2', '2', 'O', 'A', 'O', '8', '4', 'O', 'O', 'V', 'O', 'O', '5', 'H', '1', 'W', 'B', '6', '4', '9', '4', 'G', '6', '0', '5', '3', 'R', '8', 'Z', 'O', '8', 'O', '8', 'T', 'B', 'G', '2', 'A', 'N', '3', 'W', 'N', '9', 'N', 'R', '0', 'A', 'H', '9', '0', '1', '9', '7', 'S', '0', '8', '6', '7', 'O', '5', '3', '6', 'O', 'G', 'F', '2', 'P', 'H', '8', 'Z', 'V', 'B', 'J', 'J', 'T', '7', 'P', 'O', '0', 'V', 'V', 'D', 'N', 'H', '3', 'V', '0', '1', 'A', '5', 'F', 'P', '4', 'B', 'Z', '4', '8', 'N', '4', 'V', '4', '5', 'B', 'G', '6', '7', 'A', '3', 'V', 'A', 'G', 'A', '7', '8', 'L', 'O', '3', 'B', 'T', '9', 'K', 'A', '2', 'K', 'M', '3', '9', 'R', 'Z', '0', 'V', '2', 'N', '4', '6', '2', 'V', 'N', '0', 'B', 'B', 'J', 'A', 'C', 'V', '4', '0', '4', 'P', '1', 'J', '1', '6', 'T', 'D', '6', 'J', '4', '4', 'J', '3', 'B', 'A', '1', 'P', '7', 'R', '5', '7', 'B', '1', 'M', '8', '4', 'B', 'P', '1', '9', 'D', '5', '6', '8', 'G', '0', 'D', '5', '2', '1', '2', '9', 'B', 'O', 'W', '8', '8', 'A', '4', 'O', 'U', '0', '0', 'A', '8', '6', 'O', '0', '1', '5', '2', 'A', '5', 'D', '2', 'D', '3', 'O', 'T', '6', '7', 'R', '2', 'R', '1', 'G', 'O', 'K', '3', '4', 'A', '3', '7', 'W', 'D', 'D', 'R', 'B', '7', '0', '4', 'O', '9', 'O', '6', '7', 'G', 'D', '5', 'A', 'X', '8', 'A', 'D', 'J', 'A', '8', 'V', 'T', 'B', '4', 'R', '1', '3', 'O', 'D', '6', '4', 'O', '0', 'O', '9', 'B', 'A', 'O', 'D', '4', '5', 'C', '9', '5', '7', 'V', 'R', 'R', '3', 'F', '5', 'A', 'O', '1', '1', 'O', '9', 'N', 'J', 'V', 'N', '6', 'T', '2', 'R', '6', '3', '8', 'B', 'R', 'D', 'B', '5', '4', '4', 'O', 'E', 'B', 'J', 'P', '9', 'J', '8', '9', '6', '4', '1', 'K', '7', 'B', '1', 'S', '1', 'B', '4', '4', 'N', 'W', '1', 'R', '8', 'R', '5', '9', 'Z', '2', '7', 'R', 'B', 'O', 'R', '2', 'P', '1', '8', '8', 'K', 'O', 'R', '0', 'N', '3', '4', '8', '2', 'N', 'E', 'B', '7', '3', '4', 'X', 'A', 'H', 'S', 'H', '5', 'D', '1', 'S', '4', '9', '9', '3', 'R', 'O', 'P', '5', 'V', '0', '3', '5', '3', 'V', '7', 'A', 'N', 'P', 'M', 'D', 'N', 'C', 'O', 'X', '7', '1', 'G', 'S', 'A', 'D', '5', 'X', '1', '5', '4', 'O', '5', '6', '4', '3', '7', 'X', 'A', '3', '6', '5', '5', 'D', '8', 'D', 'A', 'A', 'N', 'Y', 'V', 'S', '0', '1', 'O', '7', 'J', '5', '2', '5', 'G', 'O', '9', '8', 'D', 'M', 'P', '8', 'P', 'O', '8', 'S', '6', 'W', '8', '3', '7', '6', 'B', '5', 'J', 'O', 'N', 'H', 'N', '2', '7', '0', 'P', 'H', '9', '6', '6', 'B', 'X', '4', '1', 'O', 'L', 'X', 'P', 'A', 'A', '7', '9', 'D', '6', 'D', 'D', 'P', 'V', '9', 'O', 'A', 'O', 'V', '0', 'D', '1', 'P', '8', '5', '5', '4', 'J', 'K', 'N', 'F', 'V', 'H', 'H', '1', '9', '2', '4', '5', '4', '5', 'M', 'H', 'G', 'O', 'O', '3', '9', 'P', 'Z', '1', 'A', '5', '0', 'H', 'A', '2', '2', '6', '0', 'P', '2', '1', 'J', '7', 'N', 'A', 'A', 'V', '6', '4', 'T', '4', '1', 'K', 'B', '6', '4', '5', 'T', 'D', 'B', 'O', '2', '7', '1', 'D', 'H', '8', 'R', '9', 'A', 'O', '8', 'D', '0', '8', 'A', '5', '7', 'K', '3', 'E', 'X', '3', 'A', 'C', '5', 'F', '7', '0', '3', 'S', '1', 'N', '8', 'X', 'A', 'O', 'X', 'L', 'A', '8', '0', 'V', '9', '2', '3', '3', 'N', '4', 'W', 'D', 'W', '4', 'B', 'B', 'Z', '1', '5', '5', '9', '2', '4', 'O', '2', 'J', '7', 'O', 'O', 'R', 'B', 'R', '9', '7', 'O', 'B', 'B', '1', 'B', 'A', 'D', 'W', '4', 'G', 'A', 'C', 'H', 'J', 'B', 'V', '2', 'O', '8', 'A', 'M', 'A', 'D', '9', 'S', 'B', '9', '0', '1', 'H', 'O', 'Z', 'O', '2', '9', 'O', 'O', 'J', 'A', 'K', 'O', '5', '7', '8', 'H', 'T', 'O', 'Z', '0', 'O', 'G', 'D', 'V', '8', '4', 'P', '8', '7', 'X', 'G', '9', 'S', '9', 'O', 'V', '8', '9', 'D', 'K', 'A', '5', '9', '8', 'N', '8', '8', 'X', '6', '2', '9', 'G', 'T', 'J', 'J', 'N', 'P', '3', '3', '1', 'A', 'D', '7', '2', 'N', '2', 'J', 'D', '4', 'T', '3', '8', 'V', '2', '4', 'V', '3', 'R', '7', 'A', '2', '8', '2', 'R', '2', 'R', '6', '1', '2', '7', '7', 'G', 'H', 'B', '1', 'V', 'O', 'S', '5', 'O', 'R', 'W', '8', 'O', '1', '5', '1', '4', '6', '4', 'D', '8', 'C', '8', '2', '3', 'O', '8', '7', '3', 'T', '9', 'T', '4', '7', '3', '2', '6', 'A', 'O', '2', 'S', '9', '7', '7', 'N', 'G', '9', 'O', 'X', '4', 'J', '8', '8', '5', '2', 'G', 'J', '1', '5', 'Z', '4', 'W', '6', 'R', '6', 'R', 'K', 'W', 'A', 'P', '6', 'H', '1', '8', 'O', '2', 'W', 'D', 'G', 'B', 'J', '9', 'V', 'R', '7', 'F', '5', 'N', 'M', '9', 'P', 'H', '4', '7', 'S', '1', 'V', '5', '6', 'D', 'B', 'O', 'P', 'D', 'P', 'H', '9', 'O', 'O', 'T', 'O', '1', '7', 'D', '2', '6', 'O', 'R', 'P', 'A', '0', '1', 'K', 'P', '3', 'A', '9', '6', '7', 'A', 'V', '6', '9', 'V', '2', '2', 'V', '5', '5', '2', '4', '4', 'O', 'T', '2', 'O', 'D', '7', '1', '5', 'P', 'O', '7', '9', '6', 'T', 'D', '2', '7', 'D', 'S', 'R', '3', 'H', '7', '6', 'O', '6', '0', '4', '8', 'A', 'O', '9', 'Y', 'B', '8', '2', 'V', 'R', 'K', '4', 'T', '9', 'X', 'J', '4', 'Z', 'X', '9', 'O', 'D', 'O', '3', '6', '7', 'M', 'P', '5', 'O', 'G', 'S', '2', '8', 'O', 'D', 'G', 'O', 'X', '9', '3', 'B', '3', 'V', 'X', 'S', 'S', '9', 'J', 'H', 'P', '1', '1', 'G', 'O', 'O', 'H', 'O', 'T', 'S', 'A', 'S', '5', 'O', '6', '9', 'V', 'O', 'B', 'T', '7', 'O', '5', '1', 'T', 'A', '5', 'B', '1', '4', '1', '2', 'K', 'R', '7', '3', '3', '7', 'O', 'A', '9', 'O', '4', '2', 'J', 'H', '4', '9', '1', '5', 'B', '3', 'P', 'D', '3', 'O', 'T', 'B', '2', 'K', '1', '4', 'B', 'S', 'L', '8', '0', 'D', '1', '9', '7', 'V', 'P', 'J', 'J', '3', 'A', 'A', 'B', 'V', 'H', 'H', '6', 'O', '2', '7', '8', '7', 'O', '6', '9', '0', 'T', '0', 'B', '5', '9', '1', '4', '1', '1', '7', '8', 'K', 'O', '1', 'B', 'V', 'A', 'A', '7', 'N', 'D', 'N', '0', 'O', 'R', 'S', '1', '5', '9', 'O', '8', '8', '8', 'T', '6', 'B', 'S', 'P', 'F', 'F', '3', '8', 'H', 'C', 'R', 'V', 'J', 'O', '2', '2', '8', '8', 'A', 'K', '4', '1', 'D', '8', '8', 'O', '8', '7', 'O', '1', '6', '5', '9', 'V', 'R', 'B', 'Z', '4', '9', 'R', '6', '9', '6', 'O', 'B', '3', '9', '7', '8', '7', '0', '7', 'G', '8', '3', 'B', '4', '9', 'T', '6', 'K', 'D', '3', 'B', '7', 'R', '4', 'O', '3', 'B', '3', '9', '8', 'K', '7', 'V', 'J', '4', '7', 'D', '6', '6', 'C', '6', 'R', 'A', 'T', '2', 'G', '5', '2', 'V', '7', '2', 'S', 'B', '4', '9', '0', 'S', 'T', 'D', 'O', 'P', '8', '3', 'O', '4', '2', '9', '5', '5', '6', 'B', 'O', 'G', 'N', 'X', 'A', '8', 'O', 'M', '3', 'B', '8', 'R', '8', 'O', 'O', 'O', '9', 'V', 'O', '7', 'X', 'J', '1', '3', 'A', 'S', '1', '2', '0', '4', '8', '6', 'O', 'N', 'N', '5', 'H', 'E', '5', 'N', '5', '4', '9', '6', '4', '2', '1', '3', '4', '5', 'O', '8', '1', 'K', 'B', 'A', '4', 'B', 'B', 'A', 'Y', 'O', '6', 'A', 'B', 'M', 'R', 'O', 'O', '7', 'N', 'O', '4', '2', 'O', '7', '1', '7', '9', '7', 'O', 'N', '7', '3', 'D', 'H', '4', 'O', '2', 'N', '9', 'P', '7', 'G', '1', 'P', '0', '6', '3', 'A', '8', '0', '9', '8', 'K', 'A', '2', 'A', '9', 'A', '9', '4', 'A', 'M', 'B', '6', '5', 'V', '1', '9', '6', 'J', '9', '2', '5', 'O', '8', 'X', '6', '5', 'B', '3', 'S', 'A', 'C', 'O', 'H', 'R', '8', 'S', '3', '7', 'S', '1', 'B', '1', 'A', '4', 'A', '7', '3', 'H', 'H', '8', 'N', 'V', 'T', 'D', 'D', 'A', '4', 'O', 'D', 'V', 'V', 'D', 'R', 'O', 'V', '6', 'R', 'H', '1', '0', 'B', '4', 'E', 'G', 'O', '7', '0', '9', '4', '9', 'L', '7', '6', 'O', 'G', 'R', '3', 'R', 'B', 'V', 'O', '5', '1', '1', '9', '7', '8', 'V', '7', '2', '1', 'B', 'P', 'A', 'O', 'D', '9', '2', 'R', '7', '9', '8', '2', '7', '3', 'O', '3', 'S', '8', '8', '8', 'O', 'J', '2', '6', '3', 'G', 'W', '2', 'O', 'B', '1', '7', '4', 'O', '3', '0', '7', '5', '4', 'P', 'A', 'G', '9', 'A', '3', '9', 'O', '8', '4', 'O', 'H', 'O', '7', '8', '2', 'O', 'R', 'B', '7', '4', 'K', 'D', 'K', 'O', 'M', '1', 'O', 'P', 'O', '7', 'O', 'A', '6', 'A', '6', '7', 'B', 'R', '2', '8', 'O', '2', '3', 'D', 'A', 'V', 'O', 'B', 'T', 'N', 'J', 'K', 'A', '3', 'K', '0', '7', '4', '4', '6', '0', '6', '5', 'N', 'G', '7', 'V', 'O', '7', '1', 'P', 'W', '4', '0', '1', '3', '9', '0', 'K', 'T', 'O', '6', '3', '5', '6', '8', 'R', 'O', 'S', '8', '3', '9', 'L', 'D', 'T', '6', 'N', '7', 'N', 'N', '9', '3', 'P', '1', 'P', 'H', 'O', 'N', 'H', 'S', '5', 'A', '3', '8', '2', '5', 'B', '9', 'D', 'X', '3', '2', 'X', 'T', 'P', 'X', '8', '4', '8', '1', '1', '2', 'H', '2', 'T', 'P', '1', '2', 'G', 'D', '4', '3', 'O', 'O', 'R', '1', '7', '6', 'T', '2', '6', '7', '8', 'V', '5', '1', 'R', '3', '4', '0', 'A', '3', '6', 'W', '8', '4', '6', '4', 'V', '5', 'O', 'L', 'X', '7', 'B', 'J', '7', 'X', '3', 'A', 'J', 'F', '2', 'O', 'K', 'G', '9', '0', '9', 'P', 'A', 'T', 'P', '4', '1', 'P', 'A', '7', 'X', '6', '6', '3', 'O', '0', '8', '2', '7', '6', '3', '6', '4', '2', '7', '8', 'S', 'D', 'A', '4', 'B', '0', '9', '5', 'F', 'V', 'O', '9', '4', '3', 'J', '4', 'B', 'Z', '3', 'O', '7', 'W', '5', 'O', '2', '4', '9', 'B', 'S', '2', '1', 'B', 'G', '5', 'O', 'P', '2', 'B', '8', 'K', '9', '1', '2', 'N', '5', 'D', 'R', '3', '3', '6', 'A', 'O', 'Z', '2', 'O', 'Z', '8', '6', '2', '2', '8', '9', 'R', 'J', '3', '7', '3', '5', 'S', 'B', 'R', '6', 'D', 'R', 'D', 'H', 'B', '8', 'M', '4', '9', 'S', 'V', 'R', '4', 'B', '7', 'W', '6', '8', 'A', 'A', '6', 'Z', '5', 'J', '5', 'A', '1', 'J', 'A', '2', 'V', '6', 'B', '5', '8', 'J', 'S', '6', 'B', 'O', 'O', '3', '0', '4', '8', '6', '4', '3', '1', '8', 'O', 'R', 'O', '7', 'F', 'R', 'D', '6', '5', '3', '4', 'H', 'P', '8', '9', 'O', 'Y', '7', '8', 'A', '5', 'V', '7', '2', 'S', 'N', 'B', '3', '8', 'V', '5', 'A', 'R', 'R', '4', 'D', '3', 'O', 'A', '6', '3', 'S', '9', 'A', 'N', 'J', 'V', '8', '2', 'S', '4', '0', '6', '8', 'H', '5', '5', 'M', 'O', 'P', '5', 'S', 'A', '5', 'A', '0', '2', 'T', '5', '2', 'A', '8', '5', 'O', '8', 'D', '8', '1', 'O', '5', 'P', '9', '1', '9', '2', 'S', '4', 'K', '5', '6', 'G', '0', 'B', 'T', '6', '1', 'N', 'B', '1', '2', '7', '5', 'O', 'S', 'N', '4', 'A', 'V', '3', 'D', '1', 'C', 'H', 'B', 'B', 'B', 'J', '0', '5', '7', '6', '2', '9', 'N', 'T', '1', '1', 'N', 'J', 'B', '4', '2', 'C', '3', 'K', 'S', 'W', 'D', 'F', 'O', 'A', 'A', 'N', '7', '5', '5', 'C', 'O', 'A', '7', '2', 'X', '7', 'A', '3', 'O', 'A', '3', '0', 'V', 'O', '3', '3', '2', '3', '2', 'V', 'R', '1', '6', '7', '2', '1', 'P', '3', '4', 'A', '0', 'H', 'V', '8', 'R', '5', '1', '2', '8', 'O', 'B', 'A', 'T', '7', 'A', '0', '7', 'H', '7', '9', 'D', '4', 'K', '7', '2', '1', 'M', 'J', '2', '3', 'N', '1', 'K', 'W', 'B', 'W', '0', '1', '9', 'G', '6', 'S', 'L', 'O', '5', '9', 'K', 'J', 'R', 'H', 'S', '3', '0', 'O', '7', '8', 'M', '2', '9', 'O', 'Z', '9', 'N', 'A', 'V', '2', 'M', '0', 'O', '2', '1', '6', '8', 'V', 'O', '5', '4', '9', 'O', 'O', '9', '0', 'R', 'D', 'R', 'A', '8', '6', '4', 'T', '2', '1', '8', '8', '8', '6', 'Z', 'D', 'V', 'V', 'S', 'V', 'A', 'V', 'G', '0', '3', '2', 'B', 'J', 'O', 'J', '5', '8', '2', 'A', 'A', 'P', 'O', 'P', 'C', 'M', 'D', '6', 'B', 'Z', 'N', '6', 'O', '5', 'J', 'T', 'O', 'L', '1', '7', 'H', '3', '9', '7', 'G', '6', '1', '3', '4', '3', '3', '1', '1', '6', '1', '8', '9', 'D', 'A', 'F', 'F', 'T', '6', 'A', '5', '3', '3', 'M', 'A', '6', 'K', 'W', '8', 'X', 'O', '0', 'Z', '0', '2', '1', '2', 'A', '3', 'B', '3', '6', 'O', '4', 'T', '3', 'V', 'G', '4', '3', '1', 'V', 'D', 'A', '3', 'W', 'O', 'V', '9', 'B', 'D', '1', '3', 'W', '8', '5', 'A', '7', 'J', 'D', '8', '5', '6', 'O', '1', '3', 'V', '4', 'T', '3', '9', '7', '6', 'J', '5', '6', '8', '0', 'R', 'O', 'V', 'P', 'V', 'S', 'B', '2', 'B', 'D', '5', '8', 'V', '4', '4', 'S', 'O', '5', '7', '6', 'O', 'R', '2', 'B', '1', 'L', 'K', 'A', 'B', 'O', '3', 'B', 'S', 'P', 'O', 'N', 'L', '7', 'D', '6', 'B', '0', '5', '4', '5', '2', 'N', '9', '5', 'G', '7', 'K', '2', '9', '3', '9', 'L', '1', 'A', '1', 'A', 'O', '3', 'B', '9', '6', 'Z', '4', '4', 'M', '9', '1', '1', 'R', 'D', 'B', 'H', 'R', '6', '8', '6', '1', '7', '3', '2', '9', '7', '3', 'O', '1', 'R', 'G', 'S', 'O', 'O', '8', '5', 'A', '0', 'B', '2', 'A', 'B', '5', 'M', '6', '5', '4', 'S', '3', 'B', 'T', '5', '1', 'D', 'V', 'K', 'A', 'K', 'P', '4', '2', 'F', '3', 'O', 'O', 'M', '4', '0', '1', '2', 'X', 'A', '2', 'P', 'G', 'B', 'A', '8', 'G', '7', '5', 'K', '0', '8', 'A', '8', '8', '3', 'N', 'O', '4', '4', '4', 'B', 'R', 'R', '7', '9', 'D', 'D', 'O', '9', 'R', 'A', 'J', '7', '0', 'P', '7', 'B', 'Z', '8', '6', '1', '8', '2', 'F', 'N', 'J', '3', 'B', '1', '7', '4', '3', 'N', '5', '0', '2', 'F', '6', 'V', '8', 'R', '5', '6', '5', '5', 'V', 'A', 'J', '1', 'N', '2', 'V', '9', 'B', '7', '5', '4', 'V', 'G', 'G', 'V', 'R', 'A', '5', 'B', 'D', '8', 'D', 'S', '2', '9', '6', '9', '0', 'G', '5', '9', 'O', '6', 'O', '4', 'V', '9', '6', 'P', '9', 'G', 'X', 'A', '3', '9', '5', 'O', '2', 'R', '5', 'J', 'J', 'H', '0', '5', 'Z', '0', '1', '1', '2', '6', '6', 'O', 'J', '4', 'A', 'S', '5', 'Z', 'V', '0', 'Z', 'B', 'O', 'T', 'R', '7', '3', 'O', '2', 'K', '7', '5', '1', '6', 'D', 'O', '9', '1', 'V', 'K', 'N', 'O', 'O', 'S', 'F', '7', '9', '7', '7', 'B', 'S', 'T', '4', 'G', 'D', '7', '0', 'T', '6', '0', 'V', 'B', '3', '9', '1', 'M', 'D', 'O', '5', 'G', 'D', 'R', 'X', '0', '9', '5', 'J', 'A', '2', 'V', '4', 'O', 'O', '9', '7', 'O', 'A', 'N', '1', '1', 'A', 'A', 'P', '7', '8', '5', '5', 'O', '8', 'O', '0', '1', '3', '5', '5', '9', '2', '6', 'B', 'H', '1', '6', '9', '2', '7', 'S', 'G', 'T', 'O', '1', 'O', 'T', '2', 'D', 'A', '6', '2', '9', 'D', 'V', 'O', 'O', 'V', 'A', '6', 'O', 'D', 'O', '2', 'Z', 'V', 'L', 'O', 'D', 'D', 'M', '4', '4', 'J', 'O', 'D', 'H', '0', 'H', '5', '3', '1', '9', '1', '9', '7', '2', '9', '0', '7', 'R', 'K', 'R', '9', 'A', '1', '1', 'O', 'O', 'C', 'P', '0', '8', '9', '4', '8', 'J', '1', '9', '6', 'O', 'S', 'H', 'O', '3', '3', 'T', 'K', '7', 'A', '0', '0', 'S', 'H', 'O', '6', 'L', '1', 'B', 'D', '4', 'R', '7', '3', '4', 'B', 'B', '1', 'H', 'G', 'V', 'O', 'V', 'W', '4', 'O', '4', '5', 'D', '3', '8', 'W', '1', '7', 'O', '2', 'G', 'K', '6', 'W', 'N', '0', '9', '0', '1', 'B', '6', '2', '4', '7', 'A', 'J', '6', 'C', '3', '1', '6', 'N', 'T', '2', 'S', 'A', '7', '0', 'V', '4', '2', 'O', 'O', 'S', '8', '0', 'O', 'O', '9', 'O', '8', 'O', 'O', '5', 'J', '5', 'A', '8', '3', 'R', 'H', '8', '5', 'T', '1', '3', 'R', 'J', 'R', '5', '3', '8', 'Y', '5', '5', 'P', '1', '0', 'A', '1', 'D', '4', 'S', 'P', 'R', '9', 'M', '3', 'N', '1', '5', '6', 'H', '4', '5', '7', '9', 'X', 'S', 'A', '1', '8', '7', 'F', 'B', '3', '4', 'V', 'T', 'L', '0', '3', 'J', '7', '6', 'G', '4', '5', '6', 'X', 'V', '8', '7', 'N', '3', 'P', 'D', 'O', '3', '1', '6', 'V', '5', '7', '1', '7', 'A', 'V', 'X', 'P', 'A', 'A', '1', '3', 'G', 'B', 'S', 'D', '6', 'J', '1', 'O', 'H', '0', '9', 'P', '0', '7', '3', 'H', '0', 'M', '7', '5', '6', 'V', 'R', '8', 'N', '9', '9', 'S', 'A', '1', 'V', 'B', 'A', 'B', '4', '6', 'D', 'O', '0', '7', 'O', '7', '6', 'Z', '9', '1', 'D', 'B', 'A', 'R', '3', '6', '0', 'M', '3', '5', '9', 'O', 'G', '2', 'W', '3', 'D', 'R', 'S', 'B', 'D', 'O', 'N', 'V', '4', '3', 'C', 'T', 'K', '4', 'Y', 'J', 'M', 'V', 'R', '8', 'V', 'G', '9', 'J', 'A', 'A', '8', '1', 'P', 'G', '4', 'D', 'B', 'X', 'O', 'H', 'T', '5', '6', 'X', 'H', '5', '3', 'P', '3', 'B', 'M', '3', '4', 'D', 'Z', 'V', 'B', 'D', '2', '9', '7', 'V', 'N', '7', 'Z', 'H', 'W', 'V', '0', 'O', 'O', 'P', 'P', '5', '2', 'B', '3', '3', '4', 'D', 'D', 'S', '2', '2', 'O', '6', '1', 'A', 'T', '1', 'W', '2', 'J', '2', 'V', 'M', 'B', '9', 'B', '2', '7', '7', 'R', '2', 'A', '1', '4', '1', '0', 'P', 'V', 'B', 'S', '9', 'S', 'B', '8', 'T', '5', 'L', 'D', 'A', 'D', 'X', 'M', 'A', '7', 'R', 'C', 'A', 'V', '2', '5', 'G', 'O', '4', 'O', 'A', '6', '6', 'C', 'A', 'V', 'O', '7', '9', 'A', 'O', '2', 'A', 'L', '2', '6', 'G', '1', 'B', '3', 'A', 'O', 'M', '1', '4', '9', '6', 'H', '8', '2', '3', 'O', '0', 'H', 'V', '8', '2', '0', '5', '6', '5', '6', 'Y', 'B', 'Z', 'T', '1', 'R', '3', 'L', '5', '4', 'O', '2', 'H', 'D', 'O', '6', '8', '0', 'A', '6', '2', 'S', 'K', '0', 'R', '4', 'S', '3', '6', '8', '2', '5', '3', 'A', '2', 'O', 'O', 'A', 'B', 'A', '0', 'O', 'J', '5', '6', '8', '7', 'B', 'J', '4', '2', '6', 'B', 'W', '2', '6', '1', 'D', '1', 'R', '4', 'O', 'G', '6', '7', 'R', 'A', '1', '7', '2', 'R', 'B', '4', '4', '8', '5', '6', 'O', 'B', 'V', '9', 'A', '8', 'K', '3', '0', 'O', '8', 'V', 'J', '2', 'A', '3', 'O', '5', 'Z', '8', '6', '4', 'S', 'B', 'B', 'B', 'D', 'R', '2', '2', 'J', 'H', '1', 'V', 'B', '6', 'O', '7', '4', 'J', '4', '3', 'A', 'P', '9', '5', 'K', 'A', 'M', '5', '5', 'T', 'V', 'O', '5', '7', '2', 'K', 'B', '4', '1', 'N', '7', 'O', '6', 'A', '9', 'D', 'S', '5', '1', '4', '5', 'X', 'H', '6', '3', '6', 'P', 'J', 'J', '3', 'O', '5', 'V', 'O', 'P', 'J', '7', '6', '2', '7', '6', '5', 'X', 'P', 'R', 'H', '0', 'G', '8', 'P', '7', 'K', 'C', '4', 'O', 'O', '1', 'O', 'S', 'Z', 'P', '9', '1', '9', 'A', '9', 'M', 'N', 'K', '2', 'M', '0', 'R', 'S', 'T', 'M', 'M', 'A', 'H', '2', 'O', 'B', '9', 'A', 'A', '5', 'T', 'A', 'A', 'P', 'K', 'S', 'H', '0', '6', '4', '3', '3', '8', 'O', '8', 'B', 'M', '1', 'A', '6', '3', '7', '3', 'O', '6', 'O', '2', '1', '9', 'A', 'O', 'A', '3', 'A', 'V', 'A', '9', 'T', 'V', '7', '1', '9', 'R', 'O', 'V', '1', 'O', '6', 'P', '1', 'A', '4', '2', 'X', '7', '7', '4', 'S', 'L', '1', 'D', '7', 'O', 'N', 'B', '2', '8', '1', '7', '9', 'D', 'N', '7', '4', '5', 'B', '4', 'N', 'F', 'O', 'N', 'R', '2', 'B', 'B', '9', '2', 'T', 'G', '4', 'B', '5', 'J', 'H', '4', '2', 'D', '1', 'X', 'N', 'K', 'A', 'B', 'X', '8', 'J', '1', '5', '9', 'D', 'D', '8', 'O', '1', 'Z', '8', '1', 'O', '6', 'O', 'J', '1', 'R', '9', '2', '4', '4', 'B', '8', '1', '2', 'G', '9', 'B', '8', '7', 'V', 'B', '1', '1', '8', '6', 'A', 'H', 'B', '8', '0', 'B', '5', 'D', 'M', '0', '7', '8', 'P', 'M', '9', '1', '5', '1', '2', '5', '4', 'D', '9', '0', '7', '5', 'A', 'Y', '2', 'B', '3', '2', 'K', 'O', 'N', 'D', 'B', '0', '3', '8', '2', 'H', '3', '3', 'Z', '8', '3', 'R', '5', '1', '5', '0', 'O', 'B', 'O', '0', 'G', 'D', '6', 'K', '9', '2', 'O', 'O', 'J', '0', 'K', '8', '3', 'D', '1', '4', 'A', 'R', 'B', '6', '1', 'C', 'R', '2', '3', '5', 'J', 'Z', '2', '8', '2', 'V', '3', 'O', '0', 'Z', '7', '3', 'P', '5', '5', '4', 'F', 'X', '7', 'V', '2', '8', 'Z', 'O', 'R', 'O', '7', '9', '4', '7', '3', 'O', 'D', '9', '2', 'D', '5', '2', 'V', '0', 'K', 'N', 'V', '8', '2', 'O', 'W', '1', '5', 'O', '4', '0', '8', 'H', 'A', 'K', 'B', 'H', '3', 'W', 'T', 'B', 'S', '2', 'S', '8', '7', '9', 'V', '7', 'O', 'S', 'W', '9', '1', '6', '4', '5', '0', 'C', '4', '3', '0', '6', 'P', 'B', '6', '3', 'A', 'N', 'G', '6', '7', 'O', '8', '4', '3', '4', 'B', 'G', 'Z', '7', 'B', '2', '8', 'C', 'O', 'W', 'V', 'O', 'A', 'H', '6', 'Z', 'O', 'B', 'A', 'K', 'A', 'V', 'V', '9', '1', 'D', '5', 'S', 'F', 'K', 'D', '5', 'G', 'H', 'A', '1', '4', '6', 'D', 'G', 'G', '9', 'O', 'B', 'D', 'S', '7', '7', 'B', 'J', 'B', 'K', 'P', '4', '3', '7', 'L', '1', 'R', 'R', 'P', 'T', '1', 'A', '2', 'N', 'O', '8', '0', '2', 'B', '7', '3', '8', 'O', 'T', 'D', '6', 'O', '3', 'O', 'V', 'G', '0', 'G', '7', 'L', '6', 'A', 'R', 'N', 'M', '5', '9', 'B', 'B', 'B', '2', 'P', 'N', '1', 'N', 'O', 'X', 'O', 'O', '1', 'G', '9', 'G', 'B', 'J', 'V', 'L', '0', '6', 'N', 'H', 'X', 'N', '2', 'O', 'P', 'B', '4', '2', 'R', '0', '6', 'V', 'O', 'K', 'J', '7', 'O', '1', 'P', '7', 'T', 'H', 'B', '7', 'O', 'H', '2', '6', 'V', '5', '6', '1', 'D', '5', '7', '6', '2', 'A', '6', '5', '8', 'A', 'P', '7', '5', '8', '8', '1', 'G', 'N', 'T', 'W', '1', 'V', 'W', 'R', 'K', '3', 'N', '8', '3', '2', '9', 'D', 'S', '4', 'K', '4', 'S', '8', 'O', 'H', 'Y', '3', '6', 'D', '1', 'J', '7', '7', 'O', '7', 'R', '5', '2', '9', '6', 'P', 'W', 'D', 'V', '7', 'N', '7', '3', '2', 'B', 'O', 'B', '0', 'D', 'A', '9', 'H', 'J', '8', '6', '7', 'A', '3', 'R', '3', 'K', '9', 'T', 'P', '1', 'O', '4', '3', 'D', '7', '0', '2', 'D', 'B', '9', 'O', '3', 'Z', '2', 'G', '6', 'D', '0', '5', '6', 'B', '2', 'A', '0', '8', '5', 'A', '5', 'B', '2', '0', 'O', '2', 'A', 'S', '7', '0', 'M', '6', '9', 'M', 'X', 'D', '7', 'O', '5', '0', '7', '3', '3', '9', '2', 'O', '3', 'D', 'O', 'O', 'T', 'N', '9', '7', 'D', '4', 'R', '1', '1', 'A', 'X', '5', 'B', 'G', 'O', '8', 'P', '5', 'A', 'V', '6', 'W', 'B', '1', '6', '7', '7', 'G', 'H', 'J', 'B', '7', 'L', '2', 'K', 'A', '8', '1', 'A', '9', '8', 'N', 'J', '7', '9', 'J', '0', 'A', 'A', 'J', 'B', 'B', 'G', '1', 'M', 'D', '5', '4', '2', 'T', 'V', '7', 'O', '8', '6', '0', 'W', 'T', 'A', '1', 'Z', 'A', '8', 'F', '0', '1', '2', '3', '6', 'J', '0', 'V', '6', '6', 'B', 'B', '3', 'A', 'O', 'O', 'T', '9', '6', '9', '7', '0', 'H', '0', '7', 'Z', '1', 'N', 'B', '4', '4', '6', 'B', 'N', '3', 'N', 'A', '9', 'B', 'O', 'X', '2', '7', 'W', 'J', '5', 'A', '6', 'S', '3', '8', '3', 'X', 'K', 'O', 'G', 'D', 'O', 'G', '1', '4', 'O', 'D', '5', 'L', 'H', 'B', 'E', 'P', '8', 'P', '9', 'D', '7', '2', 'K', 'R', '4', 'R', '0', 'M', '0', '9', '6', 'A', 'D', 'B', 'O', 'A', 'T', 'D', '9', '2', 'V', '0', '2', '2', '5', 'O', 'Z', '3', '9', '2', 'S', 'D', 'O', 'A', 'H', '4', '4', '1', 'G', '3', 'J', 'V', 'B', 'D', '7', 'T', '9', 'O', 'R', 'V', 'O', 'A', 'O', 'V', 'G', 'O', '4', 'O', 'J', '0', '9', '3', 'A', 'B', '3', 'J', '2', 'D', 'O', '6', 'N', 'A', 'X', 'O', '9', '3', '6', 'P', 'Y', 'A', 'A', 'B', '7', 'K', 'H', '9', 'O', 'M', '8', '7', 'X', 'G', 'O', '9', '9', 'L', 'B', '5', '1', 'L', '9', '2', '1', 'D', '5', '7', '7', '0', '4', 'A', '3', 'B', '8', '9', 'G', '2', '2', 'Y', '1', '8', 'S', '1', '6', '2', '2', '8', '6', '9', '4', 'M', '4', 'O', 'M', '8', 'D', 'O', 'A', 'V', 'T', '5', 'M', 'N', 'B', 'N', '9', 'D', '3', '4', 'S', '9', '2', 'F', '1', 'B', 'D', '8', 'T', '6', '4', '2', 'L', 'K', 'P', '3', 'Y', 'N', 'H', 'O', 'D', 'N', '8', 'B', 'V', 'R', 'O', '0', '4', 'O', 'T', 'R', 'O', '7', '1', '2', 'R', 'B', '9', 'D', '0', '2', 'M', '7', 'B', '3', 'X', '3', 'T', '6', '6', '5', 'N', '5', '6', '2', 'V', 'D', '9', '2', '9', 'P', '7', 'D', '8', '1', '1', '0', 'P', '8', '8', 'B', '7', 'N', 'R', 'O', 'T', 'G', '6', 'H', '9', '8', '3', '6', '3', '8', '6', 'X', '5', '2', 'A', 'H', 'O', '2', 'V', '5', '3', '9', 'H', '0', 'D', '4', 'H', 'A', 'R', '9', '6', 'R', 'T', '9', 'V', 'V', 'K', 'T', 'J', 'P', 'V', 'A', '0', '2', 'M', '5', '5', '8', '7', '1', 'Y', 'L', 'D', '0', 'D', 'B', 'V', '5', 'D', '5', 'V', '5', '1', 'G', '9', '0', '7', 'F', 'R', 'W', '9', '2', 'B', 'D', 'B', 'V', 'L', '6', '9', '5', '0', '1', 'P', 'B', '3', 'P', '5', 'B', 'L', 'V', 'O', 'T', '8', 'N', 'J', '1', 'O', 'P', '7', 'O', '8', 'P', '2', '7', '2', 'J', '4', '7', '0', '1', '1', 'D', 'B', 'M', 'L', '1', 'O', 'G', '3', 'W', '4', 'J', 'A', '4', '1', 'X', '7', '8', '9', '9', '5', 'V', '1', '1', 'A', 'J', '6', '5', 'G', 'M', '2', 'O', '9', 'R', 'O', '7', 'S', 'N', 'G', '6', '4', '4', 'D', '3', '1', 'D', 'Z', '5', 'O', 'O', 'A', '5', 'X', '7', '0', '0', '5', 'Y', 'M', '4', '0', '3', 'N', '7', '7', 'V', '6', 'T', 'B', 'N', 'R', '5', '8', '2', 'N', '1', 'V', '4', 'K', '6', '6', '5', 'A', 'N', 'M', 'P', 'P', '8', '9', 'Z', 'D', 'O', '3', '4', 'D', '4', 'B', 'J', '7', 'O', '9', '0', '8', '5', 'P', 'R', '5', 'S', 'T', '5', 'V', 'N', 'V', 'A', 'H', '6', 'O', '4', 'X', '3', 'A', '6', 'S', 'R', 'O', 'O', '4', 'O', '9', '0', 'A', '5', 'V', 'N', '2', '8', '8', 'B', '6', '6', 'V', 'P', '9', '0', '0', 'X', 'O', 'A', '5', '6', '8', '5', 'D', '5', '8', '3', '6', '1', '0', 'A', '7', 'Y', 'J', 'B', 'S', 'G', '4', '3', 'V', '7', 'T', 'R', 'O', '5', '7', '3', 'K', 'N', '6', '4', '8', 'W', 'P', '5', 'J', '5', 'O', 'O', '0', 'N', '2', 'A', 'D', '4', 'V', 'D', 'O', 'O', '9', 'V', '8', '2', 'A', 'D', '6', 'O', 'N', 'R', '9', 'P', 'S', 'S', 'N', '2', '3', '1', 'A', '8', '6', '5', '2', 'Y', '2', 'D', 'K', '4', 'W', '1', '0', 'B', '6', 'B', 'V', 'B', '9', '2', '3', '6', '1', 'O', '4', '4', '0', 'O', '5', 'P', '2', '0', 'O', '9', '6', '2', '3', 'V', '9', 'D', '7', '6', '9', 'W', 'R', '3', 'O', '8', 'W', '4', 'V', '9', '5', 'A', '4', '2', '3', '5', '9', 'V', 'P', '4', 'G', 'B', 'A', 'A', '6', 'O', 'B', 'Z', '7', 'D', '6', '5', '0', '8', '7', '3', '8', '8', 'L', 'V', '1', 'O', '6', '4', '9', '9', '0', '3', '3', '1', '5', 'D', 'P', 'A', 'P', 'D', 'O', 'B', 'H', 'G', 'H', '2', '7', 'B', '5', 'V', '7', '7', '1', '7', '9', 'O', '2', '7', '1', 'L', '1', 'O', 'V', 'B', '7', '1', '1', 'N', '5', 'D', 'K', 'G', '8', 'B', 'O', 'G', 'T', 'V', 'A', 'H', '4', '5', 'K', '1', 'A', '9', '1', '4', '7', 'C', 'A', 'O', '9', '6', '0', 'X', 'B', 'W', 'R', 'A', 'A', 'O', '5', '0', 'A', 'J', '6', '9', 'Z', 'O', '8', 'V', 'F', '8', 'O', 'H', '9', '2', 'A', '2', '7', '1', 'H', '8', 'D', 'P', 'R', '2', 'B', 'X', '9', '2', '7', 'J', 'C', '6', '3', 'N', '3', '7', 'N', 'O', '5', 'O', 'V', 'H', '6', '3', 'B', 'O', 'A', '0', '8', 'F', 'D', 'T', '6', '9', '1', '4', 'R', '8', '4', '2', '5', '0', '8', '9', '0', 'B', '4', '8', '6', '9', '4', 'T', '0', 'R', 'D', 'O', 'H', 'B', '7', 'A', 'J', 'H', 'V', '4', '1', 'D', 'O', '2', 'O', 'V', '5', 'A', '0', 'B', '2', '1', '4', '5', 'O', 'W', 'P', 'H', 'R', '8', '5', 'V', 'S', 'A', 'O', '1', '9', '7', '2', 'P', 'M', '4', '8', 'B', '8', '4', '3', 'P', 'Z', 'X', 'V', 'P', 'O', '4', 'V', '5', '9', '8', 'F', 'K', '4', '0', 'H', 'G', '6', 'H', 'O', '8', 'O', 'V', '2', '7', '7', 'T', '7', 'A', '6', '4', 'H', 'N', '0', 'Z', '7', '6', 'J', '6', 'G', '1', 'K', 'O', 'O', 'R', '7', 'S', 'J', '5', '8', '3', '2', '7', 'B', '3', 'S', 'L', 'W', '9', '8', '6', 'J', '2', '8', 'O', '0', 'V', '6', '8', 'R', '8', '0', '8', 'V', '7', 'A', 'A', '7', 'K', 'B', 'F', '3', 'V', 'D', 'D', 'B', 'J', 'N', 'H', '4', '8', '7', '2', 'B', 'A', 'D', '3', '2', '8', '2', 'O', '5', '1', '3', 'A', '8', '0', '0', 'N', '9', 'X', 'D', '1', '9', '7', '1', 'O', '5', '8', '5', 'J', 'S', 'D', 'N', 'P', 'R', 'O', '3', 'D', '6', 'J', 'T', '8', 'A', '4', 'B', '1', '4', 'O', 'P', 'P', 'R', '6', 'O', '2', '7', '2', 'B', 'G', '5', 'A', '7', '9', '0', '2', '2', 'B', '3', 'K', 'A', '7', 'B', '6', '5', 'W', '9', '8', 'F', 'W', 'D', 'B', '3', '2', 'A', 'G', 'R', '0', 'G', 'M', '3', '1', '6', 'B', '4', 'T', 'B', 'O', 'A', 'L', '3', 'A', '9', 'A', 'O', 'D', 'C', '4', 'T', '4', 'F', 'G', '0', 'A', '9', '4', 'N', 'O', '7', 'D', '4', '5', 'L', 'P', '5', 'V', 'A', 'B', '2', 'O', 'D', '6', '8', 'R', 'R', '8', '5', 'D', '6', 'O', '8', 'A', '5', 'O', 'Z', 'O', '0', '7', 'A', '6', 'J', 'D', '5', 'D', 'J', 'S', '2', '9', '6', '4', '7', 'A', '1', '7', 'T', '2', 'B', 'F', '9', '1', '1', '7', '0', 'V', 'J', 'O', 'T', '6', 'B', '4', '5', '7', '1', 'C', 'F', '5', '2', '7', 'B', 'O', '0', '9', '1', '2', 'K', '4', '0', 'J', 'W', 'O', 'V', '4', 'V', 'O', 'P', 'B', '0', '2', '8', '3', 'Z', '7', 'B', '5', '3', '3', 'J', '4', 'H', 'D', 'A', '7', 'D', '3', 'R', '8', '1', 'J', '7', '5', '1', 'O', '9', 'H', 'P', 'N', '8', 'P', '1', 'A', 'W', 'O', 'D', '5', 'H', '2', '1', 'M', 'S', '1', '8', '4', '1', 'S', '1', 'C', 'S', '9', '2', 'A', '6', 'K', '0', '0', '7', 'D', '8', 'O', 'O', '6', 'K', 'M', 'O', 'V', 'X', 'O', '6', 'R', 'V', '7', 'B', '6', 'W', 'D', 'D', '1', 'Z', 'V', 'N', 'R', 'B', 'O', 'G', 'A', 'H', '4', 'O', 'B', 'R', '6', 'P', 'O', '7', 'R', '8', 'D', '8', 'F', 'O', 'J', '2', '6', '1', 'S', 'M', '5', 'O', 'A', 'B', 'V', 'B', '2', '3', 'O', '9', '3', 'D', '1', 'P', '8', '6', 'H', 'W', '1', 'H', '5', 'R', 'Z', '5', '2', '3', 'P', 'O', 'B', 'S', 'J', 'D', '8', 'R', 'A', 'O', '4', '4', 'O', 'Z', 'D', 'Z', 'G', '9', 'X', '6', '0', 'D', 'P', 'D', '9', 'X', '1', '2', 'B', 'H', '2', '5', '3', '5', 'V', '4', 'D', 'W', 'L', 'K', '2', '9', 'B', '2', '6', 'O', 'T', '8', 'S', 'D', '3', '8', 'A', '9', '9', '5', '2', '2', '0', 'A', 'J', '1', '1', 'A', '6', '9', '2', '2', 'P', 'V', '6', '3', '1', 'O', 'B', 'D', '5', '1', 'M', 'M', 'O', '1', 'N', '2', 'N', 'W', 'R', '5', '5', 'Z', '7', 'O', 'O', '7', '1', 'H', 'X', 'A', '9', '0', 'N', 'O', '2', '7', '0', '9', '9', 'V', 'B', 'A', '0', 'J', 'R', '7', '4', '9', 'B', 'N', '2', '1', 'L', 'B', '9', '8', '7', '7', '7', 'R', 'D', 'G', '1', 'A', 'P', '8', 'M', '2', 'T', 'A', 'Z', '4', 'Z', '1', 'D', '2', 'T', 'A', '2', '0', '6', 'S', '7', '6', 'D', '7', 'G', 'D', '8', '0', 'S', '1', '5', 'N', 'D', 'A', '6', 'V', '6', '7', 'B', 'D', '5', 'J', 'B', '7', '3', '5', '5', 'M', 'A', '8', 'O', '7', '0', 'H', 'M', 'O', 'T', '5', '4', '5', 'V', 'B', 'O', 'O', 'P', '4', '4', 'D', 'R', 'D', '4', 'V', 'G', '6', '7', '2', 'N', 'S', '1', 'D', '9', '9', '3', '8', 'V', '2', 'C', 'O', '2', '6', '1', 'P', 'O', 'A', '3', 'R', 'A', 'V', 'G', 'B', 'J', 'D', '1', 'O', 'O', 'V', 'A', 'R', '3', '3', '7', '5', 'B', '9', '1', 'K', '3', 'Z', '7', '4', 'A', 'A', 'P', '0', 'R', '5', '0', '0', '8', '9', '6', 'O', '0', 'D', '9', 'T', '6', 'H', '5', '2', '9', '6', 'V', '8', '3', '2', 'O', '4', 'A', 'O', '0', '4', '8', '9', 'D', 'A', 'M', '9', 'O', 'K', 'J', '8', 'B', 'V', '4', 'B', 'C', 'O', 'O', '8', 'V', 'L', 'C', '6', '1', 'U', '4', 'N', '3', '4', 'D', '2', '8', '8', '9', 'T', '1', 'F', '6', 'O', '3', 'B', '6', 'B', 'B', 'B', 'M', '6', '2', '9', '3', '3', 'T', '8', '3', '1', '8', 'W', 'B', '1', 'U', 'T', 'P', 'O', '6', '7', '9', '1', 'D', 'V', 'A', 'G', '9', 'R', 'O', 'W', 'S', 'M', '2', 'B', '2', 'T', 'O', 'K', '1', 'S', '0', '4', 'O', '8', 'V', 'K', 'B', '1', 'P', 'M', 'W', '5', 'A', 'O', '9', '4', 'O', '7', '2', 'R', 'S', 'O', 'B', 'A', '3', '9', '8', 'B', '3', 'D', 'O', 'P', 'H', 'D', '4', '7', 'H', '5', '0', 'H', 'V', '9', 'V', 'P', 'H', '0', 'O', '4', '5', '9', 'G', '9', '5', 'N', 'W', 'O', '4', '1', 'O', '7', '1', 'A', 'D', 'B', 'L', 'B', 'M', 'G', '3', 'S', 'T', 'V', '6', 'A', '6', 'D', 'R', '3', 'O', 'P', '2', '4', 'P', 'V', 'O', '7', 'G', '1', '2', '5', '1', 'L', 'P', '5', 'R', '9', 'P', '5', '3', 'R', '3', 'B', 'M', 'K', '3', 'J', '9', '8', '4', 'S', 'O', 'V', '6', '3', 'K', 'B', '6', '5', '3', 'V', 'N', '3', 'M', '4', 'D', 'C', 'A', 'N', 'S', '5', '6', 'V', '4', '2', 'K', 'T', '7', '3', 'O', '8', '2', 'A', '2', 'O', 'Z', '4', '5', 'B', '8', 'A', '6', 'B', '6', 'O', '5', 'O', '1', 'O', '9', 'B', '0', '4', '2', '6', 'X', 'A', 'D', 'O', 'G', '0', '1', 'N', 'C', 'M', 'M', '6', 'B', 'P', 'P', '4', 'B', 'N', '5', '3', 'N', '8', 'B', 'H', 'A', '9', 'S', 'R', 'O', 'J', '7', '1', '2', 'J', '7', '2', 'S', '1', '3', 'B', '9', '1', 'K', 'O', '9', '1', '1', 'D', 'M', '9', '3', '5', 'O', 'D', 'T', 'W', 'O', 'A', 'B', 'V', '4', 'B', 'V', 'A', '7', 'B', 'B', '2', 'H', 'V', 'X', '5', '1', '5', '8', 'J', '9', 'K', '7', '4', '1', '2', 'D', 'N', '0', '1', 'R', 'U', 'G', 'V', 'O', '4', '4', '1', 'N', 'O', '1', 'B', 'N', 'H', 'T', '9', '9', '7', 'N', 'X', '7', 'H', '8', '5', '2', '2', '5', 'B', '5', 'V', 'Z', 'G', 'V', '3', 'V', 'T', 'R', 'B', '8', '9', 'G', '7', 'B', 'A', 'W', '7', '5', '8', 'D', '0', '8', 'D', '4', 'X', 'K', '3', '6', '6', 'P', 'O', '3', 'N', 'J', '4', 'G', '2', 'O', 'G', 'V', '6', 'C', '0', 'X', 'B', '1', 'P', 'D', 'A', 'H', '0', '7', '0', '1', 'V', '5', '5', '7', '1', 'O', 'D', 'A', '5', 'B', '0', 'A', 'X', '8', 'O', '7', '9', 'D', 'H', '9', 'O', 'P', 'H', 'M', '8', 'W', 'B', '8', 'J', '7', '8', 'T', '2', 'G', '2', 'F', 'A', 'N', '5', 'V', 'R', 'O', '4', 'M', '1', 'D', 'G', 'H', '0', 'M', 'H', '9', '4', 'G', 'X', 'O', 'B', 'O', '4', '1', 'B', 'V', 'H', '9', 'P', '7', '5', 'A', '8', 'H', 'N', 'O', 'S', '4', 'F', 'O', 'O', 'L', 'B', 'K', 'D', 'O', 'B', '0', '9', '6', 'A', '3', '8', '6', '6', 'J', '6', 'O', '3', 'Z', 'O', '5', '8', 'M', '4', '1', '2', '2', 'B', 'R', '8', '5', 'O', '0', '4', 'O', 'B', 'O', 'O', 'S', '0', 'J', '5', 'Z', 'N', 'W', 'A', 'A', '9', '9', '8', 'B', '3', '9', 'Z', 'F', 'H', '3', '0', '9', '2', '5', '6', '7', 'B', '1', '4', 'B', '1', '7', '5', '2', 'S', 'O', '2', '5', '4', 'A', 'P', '8', 'R', '4', 'A', 'A', 'R', 'M', '8', 'F', 'J', 'T', '7', 'B', '7', '7', 'P', '2', 'N', '9', '1', '6', 'A', 'R', '3', '3', 'D', '2', '3', '0', 'L', '8', 'Z', 'B', 'O', '3', 'O', '4', 'B', 'D', '7', '9', '2', 'V', '1', '4', '2', 'N', 'A', 'R', '6', '8', 'W', '3', 'W', 'J', '5', '4', '0', '2', 'O', '1', '3', '7', '7', 'G', 'S', '4', '4', 'K', '9', '3', '1', 'B', 'V', 'V', '8', '9', 'G', 'J', '7', 'A', '9', '3', 'P', '6', 'L', 'K', 'B', 'N', 'P', 'D', 'A', 'B', 'K', 'B', '0', 'V', 'B', 'L', '2', '4', '0', 'D', 'P', 'B', 'A', '4', 'B', '6', '6', 'B', 'A', '8', '9', '9', '3', '5', '3', 'D', 'O', '9', 'B', '1', '6', '0', 'S', '5', 'T', 'S', '3', '1', '9', '1', '8', 'D', 'K', 'S', '8', 'M', '1', 'R', 'K', 'O', '3', '4', '7', '5', 'K', 'H', '2', '6', 'T', 'A', '6', 'H', '4', 'A', 'L', '6', 'B', 'D', 'O', 'B', 'V', '6', '7', 'T', '8', '2', 'D', '1', '5', '3', '3', '2', 'H', '5', 'E', '5', 'O', 'D', '7', 'A', '8', 'F', '4', 'T', '4', '6', 'A', 'X', '9', 'B', 'N', '1', 'V', '5', 'B', 'O', 'R', '2', '3', '9', '5', 'R', '9', 'O', '1', 'M', 'D', '6', 'H', 'J', '4', '4', 'J', '9', 'B', '7', 'T', 'X', 'A', '1', 'J', 'P', 'S', 'J', 'S', 'O', 'S', '8', '2', 'R', 'O', 'P', 'A', '9', 'L', '3', '4', 'S', '3', '9', 'A', 'J', 'G', 'R', 'H', '0', 'O', 'D', 'K', '7', 'V', '5', '0', 'X', 'S', 'T', '9', 'S', '6', 'R', 'Z', 'V', 'R', 'N', '3', 'P', 'O', '4', '8', '5', 'K', '0', '8', 'D', '6', 'A', 'D', 'R', 'O', '4', '2', '3', '9', 'A', 'O', '2', 'S', 'O', 'S', 'O', '7', '9', '4', '2', 'V', 'G', 'O', 'R', '9', '1', 'M', 'D', 'B', 'X', '9', '7', '1', '7', '2', 'D', 'D', '1', 'B', 'V', '2', '9', '5', '6', '9', '0', 'D', '7', '4', '3', '6', 'B', '0', '6', 'N', 'N', 'Z', 'B', '6', 'O', '8', '1', 'N', 'V', 'O', 'N', 'K', '2', '6', 'N', '4', 'H', '9', '0', 'J', '7', '8', 'N', 'G', '8', 'S', 'N', '9', '1', 'V', 'A', '2', 'G', '9', '6', 'O', '8', '5', 'O', 'B', '8', 'C', 'J', 'T', '5', '3', '9', 'F', '7', '5', '5', 'V', 'A', 'V', 'C', 'A', 'J', '0', '2', 'O', '9', 'N', 'V', 'X', '6', 'B', 'N', 'J', '6', 'O', 'O', 'G', '9', 'O', '3', '5', 'R', '0', '9', '0', '5', '3', 'P', 'H', '2', 'O', '2', 'O', '7', 'K', '6', '8', '4', '3', 'R', '8', 'R', '8', '3', '7', 'A', 'O', '6', '0', 'B', 'O', '6', 'O', '1', 'Y', 'A', '9', '7', 'V', '6', 'N', 'A', 'N', 'N', 'N', 'G', '7', 'D', '9', '7', '6', '2', 'O', '0', 'K', '3', 'G', 'T', 'B', 'V', 'N', 'B', 'K', '9', '4', '9', '8', '3', 'O', 'X', '2', 'V', '4', '6', 'O', 'A', 'A', 'J', 'O', '5', 'P', 'H', 'O', '9', '5', 'D', '4', 'S', 'A', '5', '7', '6', '6', '8', '9', 'B', 'V', '4', '1', 'S', 'B', 'P', '4', 'K', 'V', 'B', '5', '1', 'B', '4', 'K', 'W', '0', 'G', 'D', '3', 'V', '7', '1', '7', '4', 'P', '2', '6', 'J', '1', '1', 'A', '8', '4', '9', 'T', 'O', '2', '4', 'O', '9', '8', '0', '1', 'S', '4', '7', '5', '5', '3', 'C', '7', 'O', 'S', 'H', 'D', '5', '8', '2', '3', 'T', '2', '3', 'G', '9', 'P', '7', 'L', '8', '3', '7', 'T', 'B', 'D', 'H', '4', 'D', '5', 'K', '9', '4', '0', '4', 'M', '0', 'B', 'D', '4', 'G', 'B', 'W', '0', 'A', '7', 'K', '8', 'M', 'L', 'B', '7', '4', 'K', 'O', '9', 'J', 'H', 'M', 'A', 'D', 'O', '1', 'B', 'X', 'Z', '3', '7', '8', '6', 'Z', 'K', '7', '1', '3', 'R', 'D', '6', '3', 'F', 'S', '1', 'O', '4', 'V', 'Y', 'A', 'O', '9', '8', '7', '8', 'G', 'D', 'R', 'A', '7', 'W', 'M', 'D', '4', '0', '6', 'D', '8', '8', 'Z', '4', 'A', 'V', '2', 'G', 'B', '4', '6', 'S', 'N', '4', '0', '9', 'A', 'G', '7', '4', 'P', '3', 'N', '2', 'J', 'B', 'P', '9', '1', '2', '0', '2', 'H', 'R', 'V', '4', '1', 'R', '7', '3', '9', 'S', '6', 'J', '7', '8', '3', '8', '4', '8', 'B', 'B', 'O', 'V', 'K', 'O', '5', 'D', 'B', '0', 'P', 'S', 'C', '5', '7', '4', '7', 'G', '8', '1', 'O', '5', 'S', 'W', 'L', 'T', 'O', '9', 'R', '1', 'R', '9', '5', 'D', '8', '0', 'A', '0', '3', '8', '9', 'R', 'A', '9', 'A', 'N', 'A', '6', '3', 'G', 'P', '4', '5', 'K', 'O', '0', 'D', 'O', 'V', 'K', '4', '8', '7', '0', 'T', 'P', 'P', '1', 'R', 'K', 'V', 'D', '3', 'S', '8', 'V', '9', '8', '5', 'G', '7', 'B', 'V', 'V', '8', '8', 'O', '7', '8', 'D', 'T', '4', 'L']
image_data = []
for i in range(7000):
    imgz = []
    #for z in range(randint(100, 200)):
    for z in range(100):
        imgz.append(bool(random.getrandbits(1)));
    image_data.append(imgz)

#print(len(image_data), len(target_data))
#print(image_data, target_data)
cross_validation(clf, 4, image_data, target_data)
clf.fit(image_data, target_data)
# Out:
# opencv version: 3.4.2
# panda version:  0.23.4
# C:\Programs\Python36\Anaconda3
# C:\Users\Rafal\Notebooks\Assignment6
# Cross Validation Result for  4  -fold
# [5.17045455 4.04328018 3.95189003 4.66052934]
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
